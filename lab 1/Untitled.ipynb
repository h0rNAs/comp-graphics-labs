# %%
import numpy as np
from PIL import Image, ImageOps
import math

# %%
img_mat = np.full((600, 800, 3), (255, 0, 255), dtype=np.uint8)

# %%
def draw_line (image, x0, y0, x1, y1, color):
    step = 1.0/100
    for t in np.arange(0, 1, step):
        x = round((1.0 - t)*x0 + t*x1)
        y = round((1.0 - t)*y0 + t*y1)
        image[y,x] = color

# %%
def draw_line (image, x0, y0, x1, y1, color):
    count = math.sqrt((x0-x1)**2 + (y0-y1)**2)
    step = 1.0/100
    for t in np.arange(0, 1, step):
        x = round((1.0 - t)*x0 + t*x1)
        y = round((1.0 - t)*y0 + t*y1)
        image[y,x] = color

# %%
def draw_line (image, x0, y0, x1, y1, color):
    for x in range(x0, x1):
        t = (x-x0)/(x1-x0)
        y = round((1.0 - t)*y0 + t*y1)
        image[y,x] = color

# %%
def draw_line (image, x0, y0, x1, y1, color):
    if x0 > x1:
        x0, x1 = x1, x0
        y0, y1 = y1, y0
    for x in range(x0, x1):
        t = (x-x0)/(x1-x0)
        y = round((1.0 - t)*y0 + t*y1)
        image[y,x] = color

# %%
def draw_line (image, x0, y0, x1, y1, color):
    xchange = False
    if abs(x0-x1) < abs(y0-y1):
        x0, y0 = y0, x0
        x1, y1 = y1, x1
        xchange = True
    for x in range(x0, x1):
        t = (x-x0)/(x1-x0)
        y = round((1.0 - t)*y0 + t*y1)
        if xchange:
            image[x,y] = color
        else:
            image[y,x] = color

# %%
def draw_line (image, x0, y0, x1, y1, color):
    xchange = False
    if abs(x0-x1) < abs(y0-y1):
        x0, y0 = y0, x0
        x1, y1 = y1, x1
        xchange = True
    if x0 > x1:
        x0, x1 = x1, x0
        y0, y1 = y1, y0
    y = y0
    dy = abs(y1-y0)/(x1-x0)
    derror = 0.0
    y_update = 1 if y1 > y0 else -1
    
    for x in range(x0, x1):
        if xchange:
            image[x,y] = color
        else:
            image[y,x] = color
        derror += dy 
        if (derror > 0.5):
            derror -= 1.0
            y += y_update

# %%
def draw_line (image, x0, y0, x1, y1, color):
    xchange = False
    if abs(x0-x1) < abs(y0-y1):
        x0, y0 = y0, x0
        x1, y1 = y1, x1
        xchange = True
    if x0 > x1:
        x0, x1 = x1, x0
        y0, y1 = y1, y0
    y = y0
    dy = 2.0*(x1 - x0)*abs(y1-y0)/(x1-x0)
    derror = 0.0
    y_update = 1 if y1 > y0 else -1
    
    for x in range(x0, x1):
        if xchange:
            image[x,y] = color
        else:
            image[y,x] = color
        derror += dy 
        if (derror > 2.0*(x1 - x0)*0.5):
            derror -= 2.0*(x1 - x0)*1.0
            y += y_update

# %%
def draw_line (image, x0, y0, x1, y1, color):
    xchange = False
    if abs(x0-x1) < abs(y0-y1):
        x0, y0 = y0, x0
        x1, y1 = y1, x1
        xchange = True
    if x0 > x1:
        x0, x1 = x1, x0
        y0, y1 = y1, y0
    y = y0
    dy = 2*abs(y1-y0)
    derror = 0.0
    y_update = 1 if y1 > y0 else -1
    
    for x in range(x0, x1):
        if xchange:
            image[x,y] = color
        else:
            image[y,x] = color
        derror += dy 
        if (derror > (x1 - x0)):
            derror -= 2*(x1 - x0)
            y += y_update

# %%
# Задание №3
file = open("model_1.obj")
v = []
for s in file:
    sp = s.split(" ")
    if sp[0] == 'v':
        print(sp)
        v.append([sp[1], sp[2], sp[3].replace('\n', '')])
# Out:
# ['v', '-0.046146', '0.050437', '0.002961\n']
# ['v', '-0.045498', '0.049687', '0.001989\n']
# ['v', '-0.045306', '0.049655', '0.002956\n']
# ['v', '-0.044879', '0.048894', '0.002394\n']
# ['v', '-0.045935', '0.050494', '0.003832\n']
# ['v', '-0.044743', '0.048768', '0.002943\n']
# ['v', '-0.044832', '0.048663', '0.001729\n']
# ['v', '-0.045060', '0.049686', '0.003665\n']
# ['v', '-0.047369', '0.051618', '0.004211\n']
# ['v', '-0.044734', '0.047890', '0.002286\n']
# ['v', '-0.044864', '0.048748', '0.001047\n']
# ['v', '-0.045207', '0.050247', '0.004572\n']
# ['v', '-0.046589', '0.051930', '0.006586\n']
# ['v', '-0.044514', '0.048749', '0.003582\n']
# ['v', '-0.044529', '0.047892', '0.003273\n']
# ['v', '-0.044835', '0.047895', '0.000493\n']
# ['v', '-0.045516', '0.051183', '0.006567\n']
# ['v', '-0.044595', '0.049433', '0.004141\n']
# ['v', '-0.047468', '0.052435', '0.006136\n']
# ['v', '-0.044784', '0.047046', '0.003008\n']
# ['v', '-0.045021', '0.046968', '0.002126\n']
# ...

# %%
# Задание №4
img_mat = np.zeros((1000,1000,3), dtype=np.uint8)
file = open("model_1.obj")
vertices = []
for s in file:
    sp = s.split(" ")
    if sp[0] == 'v':
        x, y, z = float(sp[1]), float(sp[2]), float(sp[3])
        vertices.append([x, y, z])

scale = 8000
offset = 500
for v in vertices:
    x, y, z = v
    img_mat[int(y*scale + offset - 350), int(x*scale + offset)] = 255

# %%
# Задание №5
img_mat = np.zeros((1000,1000,3), dtype=np.uint8)
file = open("model_1.obj")
vertices = []
polygons = []
for s in file:
    sp = s.split(" ")
    if sp[0] == 'v':
        x, y, z = float(sp[1]), float(sp[2]), float(sp[3])
        vertices.append([x, y, z])
    if sp[0] == 'f':
        v1, v2, v3 = sp[1].split('/')[0], sp[2].split('/')[0], sp[3].split('/')[0]
        polygons.append([v1, v2, v3])
print(polygons)
# Out:
# [['1', '2', '3'], ['4', '3', '2'], ['1', '3', '5'], ['6', '3', '4'], ['4', '2', '7'], ['5', '3', '8'], ['5', '9', '1'], ['8', '3', '6'], ['6', '4', '10'], ['7', '2', '11'], ['10', '4', '7'], ['12', '5', '8'], ['9', '5', '13'], ['6', '14', '8'], ['15', '6', '10'], ['16', '7', '11'], ['10', '7', '16'], ['12', '17', '5'], ['18', '12', '8'], ['5', '17', '13'], ['9', '13', '19'], ['6', '15', '14'], ['18', '8', '14'], ['15', '10', '20'], ['21', '10', '16'], ['17', '12', '22'], ['23', '12', '18'], ['24', '13', '17'], ['13', '25', '19'], ['26', '14', '15'], ['26', '18', '14'], ['20', '10', '21'], ['27', '15', '20'], ['21', '16', '28'], ['12', '23', '22'], ['17', '22', '29'], ['23', '18', '26'], ['24', '25', '13'], ['17', '29', '24'], ['19', '25', '30'], ['15', '31', '26'], ['20', '21', '32'], ['15', '27', '31'], ['27', '20', '32'], ['21', '28', '33'], ['23', '34', '22'], ['29', '22', '35'], ['23', '26', '34'], ['24', '36', '25'], ['37', '24', '29'], ['36', '30', '25'], ['38', '26', '31'], ['
# ...

# %%
# Задание №6
img_mat = np.zeros((1000,1000,3), dtype=np.uint8)
file = open("86m.obj")
v = []
p = []
scale = 5
offset_x = 500
offset_y = 100
for s in file:
    sp = s.split(" ")
    if sp[0] == 'v':
        x, y, z = float(sp[1]), float(sp[2]), float(sp[3])
        v.append([x, y, z])
    if sp[0] == 'f':
        v1, v2, v3 = int(sp[1].split('/')[0]), int(sp[2].split('/')[0]), int(sp[3].split('/')[0])
        p.append([v1, v2, v3])

for k in range(len(p)):
    x0 = int(v[p[k][0]-1][0] * scale + offset_x)
    y0 = int(v[p[k][0]-1][1] * scale + offset_y)
    x1 = int(v[p[k][1]-1][0] * scale + offset_x)
    y1 = int(v[p[k][1]-1][1] * scale + offset_y)
    x2 = int(v[p[k][2]-1][0] * scale + offset_x)
    y2 = int(v[p[k][2]-1][1] * scale + offset_y)
    draw_line(img_mat, x0, y0, x1, y1, 255)
    draw_line(img_mat, x1, y1, x2, y2, 255)
    draw_line(img_mat, x0, y0, x2, y2, 255)

# %%
img = Image.fromarray(img_mat, mode='RGB')
img = ImageOps.flip(img)
display(img)
# Out:
# C:\Users\rogov\AppData\Local\Temp\ipykernel_23464\759665757.py:1: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img = Image.fromarray(img_mat, mode='RGB')
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
img.save("img.png")
img.show()
